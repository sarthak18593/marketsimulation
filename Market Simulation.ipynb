# %% [markdown]
# # Market Simulation

# %% [markdown]
# ## Legend :

# %%
import pandas as pd

# %%
marketdata = pd.read_csv("ZNH9.csv",engine='python',header = None)

# %%
marketdata.head(30)
# Out:
#     0                   1         2           3           4             5   \
# 0    T  14:04:50.881623917  23331186     5875803  '00000100'            52
# 1    V  14:04:50.881623917  23331186     5875803  '00000100'            52
# 2   SS  16:45:00.000000000  23332129  '00000000'          21             0
# 3   SS  16:59:30.000000000  23350111  '00000000'          21             0
# 4    V  17:00:00.000000000  23350434     5878128  '01000000'            37
# 5   SS  17:00:00.000000000  23350463  '00000000'          15             0
# 6    T  17:00:00.000000000  23350464     5878129  '00000000'            48
# 7    m  17:00:00.000000000     98159           1           0  845629668478
# 8    m  17:00:00.000000000     98159           2           0  845629667640
# 9    m  17:00:00.000000000     98159           3           0  845629664128
# 10   m  17:00:00.000000000     98159           4           0  845629664129
# ...
